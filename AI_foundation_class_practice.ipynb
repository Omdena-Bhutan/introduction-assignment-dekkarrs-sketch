# %% [markdown]
# <a href="https://colab.research.google.com/github/Omdena-Bhutan/introduction-assignment-dekkarrs-sketch/blob/main/AI_foundation_class_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install yfinance

import yfinance as yf
import matplotlib.pyplot as plt

# Download Apple stock data
data = yf.download("AAPL", start="2023-01-01", end="2023-12-31")

# Plot closing prices
plt.plot(data['Close'])
plt.title("Apple Stock Price in 2023")
plt.xlabel("Date")
plt.ylabel("Price (USD)")
plt.show()
# Out:
# ...
# /tmp/ipython-input-696434252.py:7: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download("AAPL", start="2023-01-01", end="2023-12-31")
# [*********************100%***********************]  1 of 1 completed

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-1162667239.py in <cell line: 0>()
#       3
#       4 resp = requests.get("https://api.bankfxapi.com/v1/bank/BTCB")
# ----> 5 data = resp.json()["rates"]
#       6 df = pd.DataFrame(data)
#       7 print(df)
#
# KeyError: 'rates'
